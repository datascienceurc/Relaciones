# %% [markdown]
# <a href="https://colab.research.google.com/github/datascienceurc/Relaciones/blob/main/Relaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
plt.plot(1,1, marker="o", color="red")
plt.plot(2,1, marker="o", color="red")
plt.plot(3,1, marker="o", color="red")
plt.plot(4,1, marker="o", color="red")
plt.plot(1,2, marker="o", color="red")
plt.plot(2,2, marker="o", color="red")
plt.plot(3,2, marker="o", color="red")
plt.plot(4,2, marker="o", color="red")
plt.plot(1,3, marker="o", color="red")
plt.plot(2,3, marker="o", color="red")
plt.plot(3,3, marker="o", color="red")
plt.plot(4,3, marker="o", color="red")
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,4,9,16,25]

plt.plot(x,y, marker="o", color="red")
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,4,9,16,25]

plt.plot(x,y, "o", color="red")
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,4,9,16,25]

plt.plot(x,y, "o")
plt.show()
